# %% [markdown]
# <a href="https://colab.research.google.com/github/RubenSicchar/Jornada-Python-Ci-ncia-de-Dados-com-Python/blob/main/Ciencia_de_Dados_Feulo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#nome

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Conhecendo o Dataset

# %%
df = pd.read_csv('train.csv', index_col = 'id')

# %%
df.head(5)
# Out:
#     age          job   marital  ... euribor3m nr.employed   y
# id                              ...
# 0    52   technician  divorced  ...     4.865      5228.1  no
# 1    36   management   married  ...     4.153      5195.8  no
# 2    53  blue-collar   married  ...     4.962      5228.1  no
# 3    45  blue-collar    single  ...     0.879      5076.2  no
# 4    60    housemaid   married  ...     4.858      5191.0  no
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 37069 entries, 0 to 37068
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             37069 non-null  int64
#  1   job             36773 non-null  object
#  2   marital         37000 non-null  object
#  3   education       35505 non-null  object
#  4   default         29296 non-null  object
#  5   housing         36176 non-null  object
#  6   loan            36176 non-null  object
#  7   contact         37069 non-null  object
#  8   month           37069 non-null  object
#  9   day_of_week     37069 non-null  object
#  10  duration        37069 non-null  int64
#  11  campaign        37069 non-null  int64
#  12  pdays           37069 non-null  int64
#  13  previous        37069 non-null  int64
#  14  poutcome        37069 non-null  object
#  15  emp.var.rate    37069 non-null  float64
#  16  cons.price.idx  37069 non-null  float64
#  17  cons.conf.idx   37069 non-null  float64
#  18  euribor3m       37069 non-null  float64
#  19  nr.employed     37069 non-null  float64
#  20  y               37069 non-null  object
# dtypes: float64(5), int64(5), object(11)
# memory usage: 6.2+ MB

# %%
df.describe()
# Out:
#                 age      duration  ...     euribor3m   nr.employed
# count  37069.000000  37069.000000  ...  37069.000000  37069.000000
# mean      40.023497    258.185492  ...      3.620484   5166.966047
# std       10.412653    259.579105  ...      1.735310     72.360902
# min       17.000000      0.000000  ...      0.634000   4963.600000
# 25%       32.000000    103.000000  ...      1.344000   5099.100000
# 50%       38.000000    180.000000  ...      4.857000   5191.000000
# 75%       47.000000    319.000000  ...      4.961000   5228.100000
# max       98.000000   4918.000000  ...      5.045000   5228.100000
#
# [8 rows x 10 columns]

# %%
df.describe(include='object')
# Out:
#            job  marital          education  ... day_of_week     poutcome      y
# count    36773    37000              35505  ...       37069        37069  37069
# unique      11        3                  7  ...           5            3      2
# top     admin.  married  university.degree  ...         thu  nonexistent     no
# freq      9364    22424              10967  ...        7735        31989  32893
#
# [4 rows x 11 columns]

# %%
plt.figure(figsize=(15,5))
sns.countplot(data=df, x='education')

# %%
plt.figure(figsize=(15,5))
sns.countplot(data=df, x='education')
plt.ylabel('Contagem')
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.countplot(data=df, x='education', hue='marital')
plt.ylabel('Contagem')
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.countplot(data=df, x='job', hue='education')
plt.ylabel('Contagem')
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.countplot(data=df, x='job')
plt.ylabel('Contagem')
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.countplot(data=df, x='job')
plt.ylabel('Contagem')
plt.show()

# %%
sns.barplot(data=df, x='marital', y='age')
plt.show()

# %%
sns.countplot(data=df, x='y', hue='marital')

# %%
sns.barplot(data=df, x='marital', y='age', hue='y')

# %%
sns.barplot(data=df, x='marital', y='age', hue='y')
plt.show()

# %%
sns.catplot(data=df, x='marital', y='age', hue='y')
plt.show()

# %%
plt.figuresize=(15,5)
sns.catplot(data=df, x='marital', y='age', hue='y')

# %%
plt.figuresize=(15,5)
sns.catplot(data=df, x='marital', y='age', hue='y', jitter=0.01)

# %%
sns.fisize=(15,5)
sns.catplot(data=df, x='marital', y='age', hue='y', kind='box')

# %%
sns.fisize=(15,5)
sns.catplot(data=df, x='marital', y='age', hue='y', kind='box', aspect=8/6, height=8)

# %%
sns.fisize=(15,5)
sns.catplot(data=df, x='job', y='duration', hue='y', kind='box', aspect=8/6, height=8)

# %%
df[df.duration <=10].describe()
# Out:
#               age    duration  ...   euribor3m  nr.employed
# count  320.000000  320.000000  ...  320.000000   320.000000
# mean    38.906250    7.631250  ...    2.791716  5127.720938
# std      9.935716    2.066669  ...    1.850787    92.926943
# min     21.000000    0.000000  ...    0.655000  4963.600000
# 25%     31.000000    6.750000  ...    1.250000  5099.100000
# 50%     37.000000    8.000000  ...    1.405000  5099.100000
# 75%     46.250000    9.000000  ...    4.959000  5228.100000
# max     72.000000   10.000000  ...    4.968000  5228.100000
#
# [8 rows x 10 columns]

# %%
df[df.duration ==10].describe()
# Out:
#              age  duration   campaign  ...  cons.conf.idx  euribor3m  nr.employed
# count  62.000000      62.0  62.000000  ...      62.000000  62.000000    62.000000
# mean   41.306452      10.0   7.580645  ...     -42.317742   3.402500  5161.162903
# std     9.842345       0.0   6.592466  ...       3.553642   1.801966    81.319986
# min    24.000000      10.0   1.000000  ...     -49.500000   0.655000  4963.600000
# 25%    33.250000      10.0   3.000000  ...     -46.200000   1.283500  5099.100000
# 50%    40.500000      10.0   5.000000  ...     -42.000000   4.855500  5195.800000
# 75%    49.500000      10.0  10.750000  ...     -41.800000   4.959000  5228.100000
# max    60.000000      10.0  27.000000  ...     -34.800000   4.968000  5228.100000
#
# [8 rows x 10 columns]

# %%
df[df.duration <=60].describe()
# Out:
#                age     duration  ...    euribor3m  nr.employed
# count  3847.000000  3847.000000  ...  3847.000000  3847.000000
# mean     39.589030    35.317130  ...     3.726651  5175.361476
# std       9.424706    16.722764  ...     1.662299    66.170215
# min      19.000000     0.000000  ...     0.634000  4963.600000
# 25%      32.000000    20.000000  ...     1.354000  5099.100000
# 50%      38.000000    37.000000  ...     4.858000  5195.800000
# 75%      47.000000    51.000000  ...     4.962000  5228.100000
# max      88.000000    60.000000  ...     5.045000  5228.100000
#
# [8 rows x 10 columns]

# %%
df[df.duration <=60].count()
# Out:
# age               3847
# job               3809
# marital           3840
# education         3685
# default           2943
# housing           3756
# loan              3756
# contact           3847
# month             3847
# day_of_week       3847
# duration          3847
# campaign          3847
# pdays             3847
# previous          3847
# poutcome          3847
# emp.var.rate      3847
# cons.price.idx    3847
# cons.conf.idx     3847
# euribor3m         3847
# nr.employed       3847
# y                 3847
# dtype: int64

# %%
plt.figure(figsize=(15,5))
sns.scatterplot(x='age', y='duration', data=df, hue='y')
plt.show()
